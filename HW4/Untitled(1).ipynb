# %%
import csv
import numpy as np
# !pip install matplotlib
import matplotlib.pyplot as plt
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression


import warnings
warnings.filterwarnings("ignore")
# Out:
# Requirement already satisfied: matplotlib in ./.conda/envs/sep26/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.conda/envs/sep26/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in ./.conda/envs/sep26/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in ./.local/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in ./.conda/envs/sep26/lib/python3.11/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in ./.conda/envs/sep26/lib/python3.11/site-packages (from scikit-learn) (1.11.2)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Obtaining dependency information for joblib>=1.1.1 from https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl.metadata
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/81/12/fd4dea011af9d69e1cad05c75f3f7202cdcbeac9b712eea58ca779a72865/threadpoolctl-3.2.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 3.4 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Installing collected packages: threadpoolctl, joblib
# Successfully installed joblib-1.3.2 threadpoolctl-3.2.0

# %%
X = []
Y = []

with open('data.txt','r') as f:
    reader = csv.reader(f)
    for row in reader:
        X.append(float(row[0]))
        Y.append(float(row[1]))

# %%
# plot parameter setting
fig,ax= plt.subplots(figsize =(8,8))
fig.patch.set_facecolor('#f5f6f6')

ax.set_facecolor('#f5f6f6')
ax.axes.get_yaxis().set_visible(True)
ax.axes.get_xaxis().set_visible(True)

for loc in ['right', 'top']:
    ax.spines[loc].set_visible(False)


scatter_size = [val * 15 for val in Y]

# plotting the values
ax.scatter(X,Y,s =scatter_size ,c= '#C2BB00',edgecolor ='black')


# labeling and titles
ax.set_title('Python Demo: Linear Regression',{'font':'serif', 'size':14, 'weight':'bold', })
ax.set_xlabel('X values',{'font':'serif', 'size':12, 'weight':'bold', })
ax.set_ylabel('Y values',{'font':'serif', 'size':12, 'weight':'bold', })



fig.show()

# %%
#  splitting data into train,testing

X = np.array(X).reshape(-1,1)
Y = np.array(Y).reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25)

# Model instance
regr = LinearRegression()

# training the model
regr.fit(X_train, y_train)


# metrics and scores
print(regr.score(X_test, y_test))
# Out:
# 0.4777980657883367

# %%
# predictions

y_preds = regr.predict(X_test)

# %%
# plot parameter setting
fig,ax= plt.subplots(figsize =(10,10))
fig.patch.set_facecolor('#f5f6f6')

ax.set_facecolor('#f5f6f6')
ax.axes.get_yaxis().set_visible(True)
ax.axes.get_xaxis().set_visible(True)

for loc in ['right', 'top']:
    ax.spines[loc].set_visible(False)


scatter_size_true = [(val+1) * 15 for val in y_test]
scatter_size_preds = [(val+1) * 15 for val in y_preds]

# plotting the values
ax.scatter(X_test,y_test,s =scatter_size_true ,c= '#C2BB00',edgecolor ='black')
ax.scatter(X_test, y_preds,s =scatter_size_preds ,c= '#E1523D',edgecolor ='black')
ax.plot(X_test,y_preds,**{'linewidth':0.5,'linestyle': '--', 'color' : '#003547'}, alpha = 0.8)

# labeling and titles
ax.set_title('Python Demo: Linear Regression',{'font':'serif', 'size':14, 'weight':'bold', })
ax.set_xlabel('X values',{'font':'serif', 'size':12, 'weight':'bold', })
ax.set_ylabel('Y values',{'font':'serif', 'size':12, 'weight':'bold', })

# label
ax.text(10.5, 0,'Ground Truth',{'font':'serif', 'size':13, 'color':'#C2BB00', 'weight':'bold'}, alpha = 1)
ax.text(12.35,0 , '|',{'font':'serif', 'size':13, 'color':'grey','weight':'bold'}, alpha = 1)
ax.text(12.5, 0,'Prediction',{'font':'serif', 'size':13, 'color':'#E1523D', 'weight':'bold'}, alpha = 1)


fig.show()
